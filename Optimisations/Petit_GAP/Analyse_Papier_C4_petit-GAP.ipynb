# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append("../")

from C4theo_asymptotiqueValue_Calculus import C4_short, C4_long
# from DoubleRigidWallOverdampedBrownExp_Cython import RigidWallOverdampedLangevin3D
from Physic_function_problem import *
# import cythonised_simu_part

from scipy.integrate import quad
from scipy.io import loadmat
from scipy.optimize import curve_fit
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from numpy import trapz
import matplotlib.gridspec as gridspec
from matplotlib.collections import LineCollection
from mpltools import annotation
from scipy.optimize import curve_fit

import csv


def cm2inch(value):
    return value / 2.54

from tqdm import tqdm


from matplotlib import rc
import seaborn as sns
custom_params = {
    "xtick.direction": "in",
    "ytick.direction": "in",
    "lines.markeredgecolor": "k",
    "lines.markeredgewidth": 0.3,
    "figure.dpi": 200,
    "text.usetex": True,
    "font.family": "serif",
    "font.size":8,
    'axes.titlesize':10,
    'axes.labelsize':10,
}
# sns.set_context("notebook", rc={"lines.linewidth": 3})


sns.set_theme(context = "paper", style="ticks", rc=custom_params)

# %%
# Param fixé comme expériences
a = 1.519e-6 #1.12e-6/2
H = 4e-6
lD = 88.0e-9 #Répultion mur
kBT=1.38e-23*300
lB = 526e-9 #gravité
B = 5.0
eta=0.001

zz = np.linspace(-H+H*1e-3, H-H*1e-3, 1000)

dt = 1e-2
Nt = 10000000
Nt_sub = 1
tt = np.linspace(dt, dt*Nt, Nt)

# %%
mean_Dx = np.trapz(P_eq(zz, B, lD, lB, H)/np.trapz(P_eq(zz, B, lD, lB, H), zz)*D_x(zz, a, eta, H), zz)
mean_Dz = np.trapz(P_eq(zz, B, lD, lB, H)/np.trapz(P_eq(zz, B, lD, lB, H), zz)*D_z(zz, a, eta, H), zz)

# %%
import glob

# %% [markdown]
# # results$[Nj, dt, dX]$

# %% [markdown]
# data_calcul_pdf/ = datas petit gap sans Mersenne Twister (moyenné sur 2000 simus)
#
# data_calcul_pdf_4um/ = data petit gap (4 micron) AVEC Mersenne Twister (déjà moyénné sur 50 000 simus)

# %%
bins = 100

files = glob.glob("data_calcul_pdf_4um/*")

results = np.zeros([(len(files)), (len(np.load(files[0]))), bins])
for n, file in enumerate(files):
    result = np.load(file)
    
    for m, line in  enumerate(result):
        results[n, m, :] = list(line)

# %%
np.shape(results), 50*50000
# Out:
# ((50, 37, 100), 2500000)

# %% [markdown]
# # $\Delta X$

# %%
dt_C4 = [*np.arange(1, 10), *np.arange(10, 100, 10), *np.arange(100, 1000, 100), *np.arange(1000, 10000, 1000), 10000]
Sigma = 7
D_0 = 4e-21 / (6*np.pi*0.001*a)
dt_s_C4 = np.array(dt_C4) * dt

limits = np.sqrt(2*D_0*dt_s_C4) * Sigma

dX_hist = []
for n in range(len(dt_C4)):
    limit = limits[n]
    _, X = np.histogram([], bins = bins, range = [-limit, + limit]) 
    dX_hist.append((X[1:]+X[:-1])/2)
    
dX_hist = np.array(dX_hist)

# %% [markdown]
# # Calcul du $C_4$

# %%
C_4 = np.zeros(len(dt_s_C4))

for n in range(len(dt_s_C4)):
    dX = dX_hist[n,:]
    data = results[:,n, :]
    PDF = np.mean(data, axis=0)
    PDF = PDF / np.trapz(PDF, dX)
    X4 = np.trapz(dX**4 * PDF, dX)
    X2 = np.trapz(dX**2 * PDF, dX)
    C_4[n] = X4 - 3*X2**2

# %%
Kurtosis = np.zeros(len(dt_s_C4))

for n in range(len(dt_s_C4)):
    dX = dX_hist[n,:]
    data = results[:,n, :]
    PDF = np.mean(data, axis=0)
    PDF = PDF / np.trapz(PDF, dX)
    X4 = np.trapz(dX**4 * PDF, dX)
    X2 = np.trapz(dX**2 * PDF, dX)
    Kurtosis[n] = X4/X2**2 - 3

# %%
dtCOURT = np.linspace(1e-3, 1e2, 1000)
dtLONG = np.linspace(1e0, 5e2, 1000)
A4_theo_x = C4_court(D=D_para, Peq=P_eq, kBT=kBT, B=B, lD=lD, lB=lB, H=H, a=a, eta=eta, dx=1e-10)

# %%
D4_long_theo, C4_long_theo = C4_long(V=V, Dpara=D_para, Dperp=D_perp, Peq=P_eq, kBT=kBT, B=B, lD=lD, lB=lB, H=H, a=a, eta=eta, dx=1e-7)

D4_long_theo, C4_long_theo
# Out:
# (2.3372837889703517e-26, 2.6543806021548225e-38)

# %% [markdown]
# # PDF$(\Delta X)$

# %%
dt_s_C4[36]
# Out:
# 100.0

# %%
Ntau1 = 1
dx_1 = dX_hist[Ntau1,:]
data_1 = results[:,Ntau1, :]
Mean1 = np.mean(data_1, axis=0)
Z1 = np.trapz(Mean1, dx_1)
tau1 = dt_s_C4[Ntau1]

Ntau2 = 18
dx_2 = dX_hist[Ntau2,:]
data_2 = results[:,Ntau2, :]
Mean2 = np.mean(data_2, axis=0)
Z2 = np.trapz(Mean2, dx_2)
tau2 = dt_s_C4[Ntau2]

Ntau3 = 36
dx_3 = dX_hist[Ntau3,:]
data_3 = results[:,Ntau3, :]
Mean3 = np.mean(data_3, axis=0)
Z3 = np.trapz(Mean3, dx_3)
tau3 = dt_s_C4[Ntau3]

# %%
mean_Dx = np.trapz(P_eq(zz, B, lD, lB, H)/np.trapz(P_eq(zz, B, lD, lB, H), zz)*D_para(zz, a, eta, H), zz)
mean_Dz = np.trapz(P_eq(zz, B, lD, lB, H)/np.trapz(P_eq(zz, B, lD, lB, H), zz)*D_perp(zz, a, eta, H), zz)

dxCOURT = np.linspace(-0.5e-6, 0.5e-6, 1000)
dxMID =  np.linspace(-4e-6, 4e-6, 1000)
dxLONG =  np.linspace(-30e-6, 30e-6, 1000)

# %% [markdown]
# # PFD$x$ theorie au temps court

# %%
z0 = np.linspace(-H, H, 1000)
dxx = np.linspace(-0.5e-6, 0.5e-6, 1000)
tau1 = dt_s_C4[Ntau1]

PDF_theo_court = np.zeros(len(dxx))
# Peq = P_eq(z0, B, lD, lB, H)


def f(dx, dt, z0):
    return 1/(np.sqrt(4 * np.pi * dt * D_para(z0, a, eta, H))) * np.exp(-(dx**2)/(4 * dt * D_para(z0, a, eta, H))) 

# calcul de la PDF_dx theorique au temps court
for x in range(len(dxx)):
    PDF_theo_court[x] = np.trapz(f(dxx[x], tau1, z0) * P_eq(z0, B, lD, lB, H), z0)

# %% [markdown]
# # Fit PDF

# %%
def function_fit(xi,u2, c):
    u1 = mean_Dx
    tau = tau3
    return 1/(np.sqrt(4*np.pi*tau*u1)) * np.exp(-xi**2/(4*u1)) *( c + u2/(32*tau*u1**4)*(12*u1**2 - 12*u1*xi**2 + xi**4))

# %%
Ntau3 = -6
dx_3 = dX_hist[Ntau3,:]
tau3 = dt_s_C4[Ntau3]
xi_3 = dx_3/np.sqrt(tau3)
xiLONG = dxLONG*1e-6/tau3

def A(xi):
    return 1/(np.sqrt(4*np.pi*tau3*mean_Dx)) * np.exp(-xi**2/(4*mean_Dx)) 


Mean3_xi = Mean3 / np.trapz(Mean3, xi_3)
u1 = mean_Dx
u2 = 2*D4_long_theo

popt3, pcov3 = curve_fit(function_fit, xi_3,  Mean3_xi) #, bounds=(0, [tau1, u1, u2])
print("Fit: (u2, c) = ", popt3, "//// theory; (u2, c) = ", [u2, 1])
# Out:
# Fit: (u2, c) =  [9.08061713e-28 7.06785749e+00] //// theory; (u2, c) =  [4.6745675779407033e-26, 1]

# %%
fig = plt.figure(figsize = (3.3, 4/1.68),  tight_layout=True)
ax1 = plt.subplot(111)
# ax1.semilogy(xi_3, Mean3_xi,".", color="tab:blue")
ax1.plot(np.linspace(-3e-6, 3e-6, 1000), function_fit(np.linspace(-3e-6, 3e-6, 1000), *popt3)/A(np.linspace(-3e-6, 3e-6, 1000)) - 1, "k-")
ax1.plot(np.linspace(-3e-6, 3e-6, 1000), function_fit(np.linspace(-3e-6, 3e-6, 1000), u2, 1)/A(np.linspace(-3e-6, 3e-6, 1000)) - 1, "r-")
# ax1.set_xlim([-0.45, 0.45])
# ax1.set_ylim([1e-11, None])
ax1.set(
    xlabel = r"$\xi$ (m/$\sqrt{\mathrm{s}}$) ",
    ylabel = r"$P(\xi)$",
)
# Out:
# [Text(0.5, 0, '$\\xi$ (m/$\\sqrt{\\mathrm{s}}$) '), Text(0, 0.5, '$P(\\xi)$')]

# %%
fig = plt.figure(figsize = (3.3, 4/1.68),  tight_layout=True)
ax1 = plt.subplot(111)
ax1.semilogy(xi_3, Mean3_xi,".", color="tab:blue")
ax1.plot(np.linspace(-3e-6, 3e-6, 1000), function_fit(np.linspace(-3e-6, 3e-6, 1000), *popt3), "k-")
ax1.plot(np.linspace(-3e-6, 3e-6, 1000), function_fit(np.linspace(-3e-6, 3e-6, 1000), u2, 1), "r-")

# ax1.set_xlim([-0.45, 0.45])
# ax1.set_ylim([1e-11, None])
ax1.set(
    xlabel = r"$\xi$ (m/$\sqrt{\mathrm{s}}$) ",
    ylabel = r"$P(\xi)$",
)
# Out:
# [Text(0.5, 0, '$\\xi$ (m/$\\sqrt{\\mathrm{s}}$) '), Text(0, 0.5, '$P(\\xi)$')]

# %%
# from scipy.io import savemat

# mdic = {"dx": dx_3, "PDF_x": np.sum(data_3, axis=0), "H": H , "dt" : tau3,"label": "Same parameter than experience except H = 4 micron. Units in international system."}
# # mdic
# savemat("Numerical_PDF_dx_&_dt_"+str(tau3).replace(".","p")+".mat", mdic)

# %%
fig = plt.figure(figsize = (3.3, 16/1.68),  tight_layout=True)

# C4
ax0= plt.subplot(511)
ax0.plot(dtCOURT, A4_theo_x*dtCOURT**2, "-", color="peru")
ax0.plot(dtLONG, D4_long_theo*dtLONG-C4_long_theo, "--", color="peru")
ax0.loglog(dt_s_C4, C_4, ".", )
ax0.annotate(r"$\tau _1$", (dt_s_C4[Ntau1], C_4[Ntau1]*1.05), 
             xytext=(dt_s_C4[Ntau1], C_4[Ntau1]*100), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0.annotate(r"$\tau _2$", (dt_s_C4[Ntau2], C_4[Ntau2]/1.05), 
             xytext=(dt_s_C4[Ntau2], C_4[Ntau2]/500), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0.annotate(r"$\tau _3$", (dt_s_C4[Ntau3], C_4[Ntau3]/1.05),
             xytext=(dt_s_C4[Ntau3], C_4[Ntau3]/500), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0.set(
    # xlabel = r"$\tau$ $(\mathrm{s})$",
    ylabel = r"$\langle X^4_t \rangle_c$",
)
ax0.set_xlim([5e-3, 2e2])
ax0.set_ylim([1e-32, 1e-22])
ax0.text(7e-3, 1e-23, r"(a)", transform=ax0.transData)
ax0.set_title(r"$H=$ "+ str(H*1e6) + r" $\mu$m")
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax0.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,numticks=100)
ax0.yaxis.set_minor_locator(locmin)
ax0.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())





# KURTOSIS
ax0p5= plt.subplot(512)
ax0p5.plot(dtCOURT, np.ones(len(dtCOURT))*A4_theo_x/(4*mean_Dx**2), "-", color="peru")
ax0p5.plot(np.linspace(1e1, 3e2, 1000), D4_long_theo/(4*mean_Dx**2) / np.linspace(1e1, 3e2, 1000) , "--", color="peru")
ax0p5.loglog(dt_s_C4, Kurtosis, ".",)

ax0p5.annotate(r"$\tau _1$", (dt_s_C4[Ntau1], Kurtosis[Ntau1]/1.05), 
             xytext=(dt_s_C4[Ntau1], Kurtosis[Ntau1]/3), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0p5.annotate(r"$\tau _2$", (dt_s_C4[Ntau2], Kurtosis[Ntau2]/1.05), 
             xytext=(dt_s_C4[Ntau2], Kurtosis[Ntau2]/3), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0p5.annotate(r"$\tau _3$", (dt_s_C4[Ntau3], Kurtosis[Ntau3]/1.05),
             xytext=(dt_s_C4[Ntau3], Kurtosis[Ntau3]/3), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)

ax0p5.set(
    xlabel = r"$\tau$ $(\mathrm{s})$",
    ylabel = r"$\frac{\langle X^4 \rangle }{ \langle X^2 \rangle^2} - 3$",
)
ax0p5.set_xlim([5e-3, 2e2])
ax0p5.set_ylim([4e-3, 1.2e-1])
ax0p5.text(7e-3, 0.9e-1, r"(b)", transform=ax0p5.transData)
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax0p5.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax0p5.yaxis.set_minor_locator(locmin)
ax0p5.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())







#PDF1
ax1 = plt.subplot(513)
Min = np.min(data_1, axis=0)
Max = np.max(data_1, axis=0)
gauss1 = gauss(x=dxCOURT, mu=0, std=np.sqrt(2*mean_Dx*dt_s_C4[Ntau1]))

ax1.semilogy(dxx*1e6, PDF_theo_court/np.trapz(PDF_theo_court, dxx*1e6), "-k", linewidth=1.4,)
ax1.semilogy(dxCOURT*1e6, gauss1/np.trapz(gauss1, dxCOURT*1e6)  , "--", color="grey", linewidth=1,)
ax1.semilogy(dx_1*1e6, Mean1/np.trapz(Mean1, dx_1*1e6),".", color="tab:blue")
# ax1.fill_between(dx_1*1e6, Min /np.trapz(Mean1, dx_1*1e6), Max /np.trapz(Mean1, dx_1*1e6), color='blue', alpha=0.1)
ax1.text(0.23, 5e0, r"$\tau_1 = $ "+ str(dt_s_C4[Ntau1]) + " s", fontsize=8)
ax1.set_xlim([-0.45, 0.45])
ax1.set_ylim([1e-11, 5e1])
ax1.set(
    # xlabel = r"$\Delta x$ ($\mu$m)",
    ylabel = r"$P( X)$ ($\mu$m$^{-1}$)",
)
ax1.text(-0.42, 5, r"(c)", transform=ax1.transData)
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax1.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax1.yaxis.set_minor_locator(locmin)
ax1.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())







# PDF2
ax2 = plt.subplot(514)
Mean2 = np.mean(data_2, axis=0)
Min = np.min(data_2, axis=0)
Max = np.max(data_2, axis=0)
Z2 = np.trapz(Mean2, dx_2*1e6)
gauss2 = gauss(x=dxMID, mu=0, std=np.sqrt(2*mean_Dx*dt_s_C4[Ntau2]))

ax2.semilogy(dxMID*1e6, gauss2/np.trapz(gauss2, dxMID*1e6) , "--", color="grey", linewidth=1,)
ax2.semilogy(dx_2*1e6, Mean2/Z2,".", color="tab:blue")
# ax2.fill_between(dx_2*1e6, Min/Z2, Max/Z2, color='blue', alpha=0.1)


ax2.set_xlim(-3, 3)
ax2.set_ylim(1e-10, 5e0)
ax2.text(1.6, 5e-1, r"$\tau_2 = $ "+ str(dt_s_C4[Ntau2]) + " s", fontsize=8)
ax2.set(
    # xlabel = r"$\Delta x$ ($\mu$m)",
    ylabel = r"$P( X)$ ($\mu$m$^{-1}$)",
)
ax2.text(-2.8, 7e-1, r"(d)", transform=ax2.transData)
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax2.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,numticks=100)
ax2.yaxis.set_minor_locator(locmin)
ax2.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())






# PDF3
ax3 = plt.subplot(515)
Mean3 = np.mean(data_3, axis=0)
Min = np.min(data_3, axis=0)
Max = np.max(data_3, axis=0)
Z2 = np.trapz(Mean3, dx_2*1e6)
gauss3 = gauss(x=dxLONG, mu=0, std=np.sqrt(2*mean_Dx*dt_s_C4[Ntau3]))

ax3.semilogy(dxLONG*1e6, gauss3/np.trapz(gauss3, dxLONG*1e6) , "--", color="grey", linewidth=1,)
ax3.semilogy(dx_3*1e6, Mean3/ np.trapz(Mean3, dx_3*1e6), ".", color="tab:blue")
# ax3.fill_between(dx_3*1e6, Min / np.trapz(Mean3, dx_3*1e6), Max / np.trapz(Mean3, dx_3*1e6), color='blue', alpha=0.1)

ax3.set_xlim(-18, 18)
ax3.set_ylim(1e-8, 5e-1)
ax3.text(9 , 1e-1, r"$\tau_3 = $ "+ str(dt_s_C4[Ntau3]) + " s", fontsize=8)
ax3.set(
    xlabel = r"$ X$ ($\mu$m)",
    ylabel = r"$P( X)$ ($\mu$m$^{-1}$)",
)
ax3.text(-16.5, 1.5e-1, r"(e)", transform=ax3.transData)  

locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax3.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax3.yaxis.set_minor_locator(locmin)
ax3.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())


fig.tight_layout()

# plt.savefig("../Figures/Simu_C4-Kurtosis-PDF_Petit-Gap_H-4micron.pdf")

# %% [markdown]
# # Teste sur des petits gap avec Mersenne Twister

# %%
# # test = np.load("../a.npy")
# test = np.load("data_calcul_pdf_4um/1.npy")
# dx_test = np.linspace(-2.3e-6, 2.3e-6, 1000)
# Color= ["blue", "orange", "green"]

# for n, i in enumerate([0, 10, 15]):
#     plt.semilogy(dX_hist[i,:], test[i,:] / np.trapz(test[i,:], dX_hist[i,:]), ".", color=Color[n])
#     gaussian = gauss(x=dx_test, mu=0, std=np.sqrt(2*mean_Dx*dt_s_C4[i]))
#     plt.plot(dx_test, gaussian/np.trapz(gaussian,dx_test), "-", color=Color[n])

# plt.ylim([1e-3, 1e8])
# plt.xlim([-2.3e-6, 2.3e-6])
# plt.savefig("../Figures/Test-AlgoMersenne_Petit-Gap.pdf")

# %%
from matplotlib.ticker import FormatStrFormatter

# %%
fig = plt.figure(figsize = (11, 4),  tight_layout=True)

gs = mpl.gridspec.GridSpec(6,6)
# C4
ax0 = plt.subplot(gs[0:3, 0])


ax0.plot(dtCOURT, A4_theo_x*dtCOURT**2, "-", color="peru")
ax0.plot(dtLONG, D4_long_theo*dtLONG-C4_long_theo, "--", color="peru")
ax0.loglog(dt_s_C4, C_4, ".", )
ax0.annotate(r"$\tau _1$", (dt_s_C4[Ntau1], C_4[Ntau1]*1.05), 
             xytext=(dt_s_C4[Ntau1], C_4[Ntau1]*100), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0.annotate(r"$\tau _2$", (dt_s_C4[Ntau2], C_4[Ntau2]/1.05), 
             xytext=(dt_s_C4[Ntau2], C_4[Ntau2]/500), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0.annotate(r"$\tau _3$", (dt_s_C4[Ntau3], C_4[Ntau3]/1.05),
             xytext=(dt_s_C4[Ntau3], C_4[Ntau3]/500), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0.set(
    # xlabel = r"$\tau$ $(\mathrm{s})$",
    ylabel = r"$\langle X^4_t \rangle_\mathrm{c}$",
)
ax0.set_xlim([5e-3, 2e2])
ax0.set_ylim([1e-32, 1e-22])
ax0.text(0.08, 0.9, r"(a)", transform=ax0.transAxes)
# ax0.set_title(r"$H=$ "+ str(H*1e6) + r" $\mu$m")
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax0.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,numticks=100)
ax0.yaxis.set_minor_locator(locmin)
ax0.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())





# KURTOSIS
ax0p5= plt.subplot(gs[3:6, 0])
ax0p5.plot(dtCOURT, np.ones(len(dtCOURT))*A4_theo_x/(4*mean_Dx**2), "-", color="peru")
ax0p5.plot(np.linspace(1e1, 3e2, 1000), D4_long_theo/(4*mean_Dx**2) / np.linspace(1e1, 3e2, 1000) , "--", color="peru")
ax0p5.loglog(dt_s_C4, Kurtosis, ".", markersize=12)

ax0p5.annotate(r"$\tau _1$", (dt_s_C4[Ntau1], Kurtosis[Ntau1]/1.05), 
             xytext=(dt_s_C4[Ntau1], Kurtosis[Ntau1]/3), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0p5.annotate(r"$\tau _2$", (dt_s_C4[Ntau2], Kurtosis[Ntau2]/1.05), 
             xytext=(dt_s_C4[Ntau2], Kurtosis[Ntau2]/3), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0p5.annotate(r"$\tau _3$", (dt_s_C4[Ntau3], Kurtosis[Ntau3]/1.05),
             xytext=(dt_s_C4[Ntau3], Kurtosis[Ntau3]/3), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)

ax0p5.set(
    xlabel = r"$\tau$ $(\mathrm{s})$",
    ylabel = r"$\frac{\langle X^4 \rangle }{ \langle X^2 \rangle^2} - 3$",
)
ax0p5.set_xlim([5e-3, 2e2])
ax0p5.set_ylim([4e-3, 1.2e-1])
ax0p5.text(0.08, 0.9, r"(b)", transform=ax0p5.transAxes)
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax0p5.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax0p5.yaxis.set_minor_locator(locmin)
ax0p5.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())







#PDF1´
ax1 = plt.subplot(gs[0:2, 1])
Min = np.min(data_1, axis=0)
Max = np.max(data_1, axis=0)
gauss1 = gauss(x=dxCOURT, mu=0, std=np.sqrt(2*mean_Dx*dt_s_C4[Ntau1]))

ax1.semilogy(dxx*1e6, PDF_theo_court/np.trapz(PDF_theo_court, dxx*1e6), "-k", linewidth=1.4,)
ax1.semilogy(dxCOURT*1e6, gauss1/np.trapz(gauss1, dxCOURT*1e6)  , "--", color="grey", linewidth=1,)
ax1.semilogy(dx_1*1e6, Mean1/np.trapz(Mean1, dx_1*1e6),".", color="tab:blue", markersize=12)
# ax1.fill_between(dx_1*1e6, Min /np.trapz(Mean1, dx_1*1e6), Max /np.trapz(Mean1, dx_1*1e6), color='blue', alpha=0.1)
# ax1.text(0.23, 5e0, r"$\tau_1 = $ "+ str(dt_s_C4[Ntau1]) + " s", fontsize=8)
ax1.set_xlim([-0.45, 0.45])
ax1.set_ylim([1e-11, 5e1])
ax1.set(
    xlabel = r"$x$ ($\mu$m)",
    ylabel = r"$p( x, \tau_1)$ ($\mu$m$^{-1}$)",
)
ax1.text(0.08, 0.8, r"(c)", transform=ax1.transAxes)
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax1.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax1.yaxis.set_minor_locator(locmin)
ax1.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())







# PDF2
ax2 =  plt.subplot(gs[2:4, 1])
Mean2 = np.mean(data_2, axis=0)
Min = np.min(data_2, axis=0)
Max = np.max(data_2, axis=0)
Z2 = np.trapz(Mean2, dx_2*1e6)
gauss2 = gauss(x=dxMID, mu=0, std=np.sqrt(2*mean_Dx*dt_s_C4[Ntau2]))

ax2.semilogy(dxMID*1e6, gauss2/np.trapz(gauss2, dxMID*1e6) , "--", color="grey", linewidth=1,)
ax2.semilogy(dx_2*1e6, Mean2/Z2,".", color="tab:blue")
# ax2.fill_between(dx_2*1e6, Min/Z2, Max/Z2, color='blue', alpha=0.1)


ax2.set_xlim(-3, 3)
ax2.set_ylim(1e-10, 5e0)
# ax2.text(1.6, 5e-1, r"$\tau_2 = $ "+ str(dt_s_C4[Ntau2]) + " s", fontsize=8)
ax2.set(
    xlabel = r"$x$ ($\mu$m)",
    ylabel = r"$p( x, \tau_2)$ ($\mu$m$^{-1}$)",
)
ax2.text(0.08, 0.8, r"(d)", transform=ax2.transAxes)
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax2.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,numticks=100)
ax2.yaxis.set_minor_locator(locmin)
ax2.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())






# PDF3
ax3 = plt.subplot(gs[4:6, 1])
Mean3 = np.mean(data_3, axis=0)
Min = np.min(data_3, axis=0)
Max = np.max(data_3, axis=0)
Z2 = np.trapz(Mean3, dx_2*1e6)
gauss3 = gauss(x=dxLONG, mu=0, std=np.sqrt(2*mean_Dx*dt_s_C4[Ntau3]))

ax3.semilogy(dxLONG*1e6, gauss3/np.trapz(gauss3, dxLONG*1e6) , "--", color="grey", linewidth=1,)
ax3.semilogy(dx_3*1e6, Mean3/ np.trapz(Mean3, dx_3*1e6), ".", color="tab:blue")
# ax3.fill_between(dx_3*1e6, Min / np.trapz(Mean3, dx_3*1e6), Max / np.trapz(Mean3, dx_3*1e6), color='blue', alpha=0.1)

ax3.set_xlim(-18, 18)
ax3.set_ylim(1e-8, 5e-1)
# ax3.text(9 , 1e-1, r"$\tau_3 = $ "+ str(dt_s_C4[Ntau3]) + " s", fontsize=8)
ax3.set(
    xlabel = r"$x$ ($\mu$m)",
    ylabel = r"$p( x, \tau_3)$ ($\mu$m$^{-1}$)",
)
ax3.text(0.08, 0.8, r"(e)", transform=ax3.transAxes)

locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax3.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax3.yaxis.set_minor_locator(locmin)
ax3.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())


ax3_ticks = ax3.get_yticklabels()
for i in ax3_ticks:
    i.set_visible(False)
    
for n, i in enumerate(ax3_ticks):
    if n%2==0:i.set_visible(True)
    

ax1_ticks = ax1.get_yticklabels()
for i in ax1_ticks:
    i.set_visible(False)
    
for n, i in enumerate(ax1_ticks):
    if n%2==0:i.set_visible(True)


###    
ax2_ticks = ax2.get_yticklabels()
for i in ax2_ticks:
    i.set_visible(False)
    
for n, i in enumerate(ax2_ticks):
    if n%2==0:i.set_visible(True)
    

    
# ###
ax0_ticks = ax0.get_xticklabels()
for i in ax0_ticks:
    i.set_visible(False)
    
for n, i in enumerate(ax0_ticks):
    if n%2==0:i.set_visible(True)
# ###

# axKU_ticks = axKU.get_xticklabels()
# for i in axKU_ticks:
#     i.set_visible(False)
    
# for n, i in enumerate(axKU_ticks):
#     if n%2==0:i.set_visible(True)

locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax0.xaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax0.xaxis.set_minor_locator(locmin)
ax0.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())

ax1.xaxis.set_major_formatter(FormatStrFormatter('%g'))


fig.tight_layout(pad = 0.001)



fig.savefig("../Figures/Simu_C4-Kurtosis-PDF_Petit-Gap_H-4micron.pdf", bbox_inches = "tight")

# %%
fig = plt.figure(figsize = (2*3.375, 10),  tight_layout=True)

gs = mpl.gridspec.GridSpec(6,6)
# C4
ax0 = plt.subplot(gs[0, :])


ax0.plot(dtCOURT, A4_theo_x*dtCOURT**2, "-", color="peru", linewidth=1.5)
ax0.plot(dtLONG, D4_long_theo*dtLONG-C4_long_theo, "--", color="peru", linewidth=1.5)
ax0.loglog(dt_s_C4, C_4, ".", color="tab:blue", markersize=8)
ax0.annotate(r"$\tau _1$", (dt_s_C4[Ntau1], C_4[Ntau1]*1.05), 
             xytext=(dt_s_C4[Ntau1], C_4[Ntau1]*100), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0.annotate(r"$\tau _2$", (dt_s_C4[Ntau2], C_4[Ntau2]/1.05), 
             xytext=(dt_s_C4[Ntau2], C_4[Ntau2]/500), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0.annotate(r"$\tau _3$", (dt_s_C4[Ntau3], C_4[Ntau3]/1.05),
             xytext=(dt_s_C4[Ntau3], C_4[Ntau3]/500), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0.set(
    # xlabel = r"$\tau$ $(\mathrm{s})$",
    ylabel = r"$\langle X^4_t \rangle_\mathrm{c}$ $(\mathrm{m}^4)$",
)
ax0.set_xlim([5e-3, 2e2])
ax0.set_ylim([1e-32, 1e-22])
ax0.text(0.02, 0.9, r"(a)", transform=ax0.transAxes)
# ax0.set_title(r"$H=$ "+ str(H*1e6) + r" $\mu$m")
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax0.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,numticks=100)
ax0.yaxis.set_minor_locator(locmin)
ax0.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())





# KURTOSIS
ax0p5= plt.subplot(gs[1, :])
ax0p5.plot(dtCOURT, np.ones(len(dtCOURT))*A4_theo_x/(4*mean_Dx**2), "-", color="peru", linewidth=1.5)
ax0p5.plot(np.linspace(1e1, 3e2, 1000), D4_long_theo/(4*mean_Dx**2) / np.linspace(1e1, 3e2, 1000) , "--", color="peru", linewidth=1.5)
ax0p5.loglog(dt_s_C4, Kurtosis, ".", color="tab:blue", markersize=8)

ax0p5.annotate(r"$\tau _1$", (dt_s_C4[Ntau1], Kurtosis[Ntau1]/1.05), 
             xytext=(dt_s_C4[Ntau1], Kurtosis[Ntau1]/3), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0p5.annotate(r"$\tau _2$", (dt_s_C4[Ntau2], Kurtosis[Ntau2]/1.05), 
             xytext=(dt_s_C4[Ntau2], Kurtosis[Ntau2]/3), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)
ax0p5.annotate(r"$\tau _3$", (dt_s_C4[Ntau3], Kurtosis[Ntau3]/1.05),
             xytext=(dt_s_C4[Ntau3], Kurtosis[Ntau3]/3), ha="center",
            arrowprops=dict(arrowstyle = "->", lw = 0.8, color= "k"), fontsize=10)

ax0p5.set(
    xlabel = r"$\tau$ $(\mathrm{s})$",
    ylabel = r"$\frac{\langle X_t^4 \rangle }{ \langle X_t^2 \rangle^2} - 3$",
)
ax0p5.set_xlim([5e-3, 2e2])
ax0p5.set_ylim([4e-3, 1.2e-1])
ax0p5.text(0.02, 0.9, r"(b)", transform=ax0p5.transAxes)
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax0p5.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax0p5.yaxis.set_minor_locator(locmin)
ax0p5.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())







#PDF1´
ax1 = plt.subplot(gs[2, 0:2])
Min = np.min(data_1, axis=0)
Max = np.max(data_1, axis=0)
gauss1 = gauss(x=dxCOURT, mu=0, std=np.sqrt(2*mean_Dx*dt_s_C4[Ntau1]))

ax1.semilogy(dxx*1e6, PDF_theo_court/np.trapz(PDF_theo_court, dxx*1e6), "-k", linewidth=1.5,)
ax1.semilogy(dxCOURT*1e6, gauss1/np.trapz(gauss1, dxCOURT*1e6)  , "--", color="grey", linewidth=1.5,)
ax1.semilogy(dx_1*1e6, Mean1/np.trapz(Mean1, dx_1*1e6),".", color="tab:blue", markersize=8)
# ax1.fill_between(dx_1*1e6, Min /np.trapz(Mean1, dx_1*1e6), Max /np.trapz(Mean1, dx_1*1e6), color='blue', alpha=0.1)
# ax1.text(0.23, 5e0, r"$\tau_1 = $ "+ str(dt_s_C4[Ntau1]) + " s", fontsize=8)
ax1.set_xlim([-0.45, 0.45])
ax1.set_ylim([1e-11, 5e1])
ax1.set(
    xlabel = r"$x$ ($\mu$m)",
    ylabel = r"$p( x, \tau_1)$ ($\mu$m$^{-1}$)",
)
ax1.text(0.07, 0.9, r"(c)", transform=ax1.transAxes)
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax1.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax1.yaxis.set_minor_locator(locmin)
ax1.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())







# PDF2
ax2 =  plt.subplot(gs[2, 2:4])
Mean2 = np.mean(data_2, axis=0)
Min = np.min(data_2, axis=0)
Max = np.max(data_2, axis=0)
Z2 = np.trapz(Mean2, dx_2*1e6)
gauss2 = gauss(x=dxMID, mu=0, std=np.sqrt(2*mean_Dx*dt_s_C4[Ntau2]))
ax2.semilogy(dxMID*1e6, gauss2/np.trapz(gauss2, dxMID*1e6) , "--", color="grey", linewidth=1.5,)
ax2.semilogy(dx_2*1e6, Mean2/Z2,".", color="tab:blue", markersize=8)
# ax2.fill_between(dx_2*1e6, Min/Z2, Max/Z2, color='blue', alpha=0.1)


ax2.set_xlim(-3, 3)
ax2.set_ylim(1e-10, 5e0)
# ax2.text(1.6, 5e-1, r"$\tau_2 = $ "+ str(dt_s_C4[Ntau2]) + " s", fontsize=8)
ax2.set(
    xlabel = r"$x$ ($\mu$m)",
    ylabel = r"$p( x, \tau_2)$ ($\mu$m$^{-1}$)",
)
ax2.text(0.07, 0.9, r"(d)", transform=ax2.transAxes)
locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax2.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,numticks=100)
ax2.yaxis.set_minor_locator(locmin)
ax2.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())






# PDF3
ax3 = plt.subplot(gs[2, 4:6])
Mean3 = np.mean(data_3, axis=0)
Min = np.min(data_3, axis=0)
Max = np.max(data_3, axis=0)
Z2 = np.trapz(Mean3, dx_2*1e6)
gauss3 = gauss(x=dxLONG, mu=0, std=np.sqrt(2*mean_Dx*dt_s_C4[Ntau3]))
ax3.semilogy(dxLONG*1e6, gauss3/np.trapz(gauss3, dxLONG*1e6) , "--", color="grey", linewidth=1.5,)
ax3.semilogy(dx_3*1e6, Mean3/ np.trapz(Mean3, dx_3*1e6), ".", color="tab:blue", markersize=8)
# ax3.fill_between(dx_3*1e6, Min / np.trapz(Mean3, dx_3*1e6), Max / np.trapz(Mean3, dx_3*1e6), color='blue', alpha=0.1)

ax3.set_xlim(-19, 19)
ax3.set_ylim(1e-9, 5e-1)
# ax3.text(9 , 1e-1, r"$\tau_3 = $ "+ str(dt_s_C4[Ntau3]) + " s", fontsize=8)
ax3.set(
    xlabel = r"$x$ ($\mu$m)",
    ylabel = r"$p( x, \tau_3)$ ($\mu$m$^{-1}$)",
)
ax3.text(0.07, 0.9, r"(e)", transform=ax3.transAxes)

locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax3.yaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax3.yaxis.set_minor_locator(locmin)
ax3.yaxis.set_minor_formatter(mpl.ticker.NullFormatter())


ax3_ticks = ax3.get_yticklabels()
for i in ax3_ticks:
    i.set_visible(False)
    
for n, i in enumerate(ax3_ticks):
    if n%2==0:i.set_visible(True)
    

ax1_ticks = ax1.get_yticklabels()
for i in ax1_ticks:
    i.set_visible(False)
    
for n, i in enumerate(ax1_ticks):
    if n%2==0:i.set_visible(True)


###    
ax2_ticks = ax2.get_yticklabels()
for i in ax2_ticks:
    i.set_visible(False)
    
for n, i in enumerate(ax2_ticks):
    if n%2==0:i.set_visible(True)
    

    
# ###
# ax0_ticks = ax0.get_xticklabels()
# for i in ax0_ticks:
#     i.set_visible(False)
    
# for n, i in enumerate(ax0_ticks):
#     if n%2==0:i.set_visible(True)
# ###

# axKU_ticks = axKU.get_xticklabels()
# for i in axKU_ticks:
#     i.set_visible(False)
    
# for n, i in enumerate(axKU_ticks):
#     if n%2==0:i.set_visible(True)

locmaj = mpl.ticker.LogLocator(base=10.0, subs=(1.0, ), numticks=100)
ax0.xaxis.set_major_locator(locmaj)
locmin = mpl.ticker.LogLocator(base=10.0, subs=np.arange(2, 10) * .1,
                                      numticks=100)
ax0.xaxis.set_minor_locator(locmin)
ax0.xaxis.set_minor_formatter(mpl.ticker.NullFormatter())

ax1.xaxis.set_major_formatter(FormatStrFormatter('%g'))


fig.tight_layout(pad = 0.001, h_pad=0.1)



fig.savefig("../Figures/Simu_C4-Kurtosis-PDF_Petit-Gap_H-4micron_V2.pdf", bbox_inches = "tight")

# %%
# data_plot_PetitGap = {}
# data_plot_PetitGap["LagTime_simu"] = dt_s_C4
# data_plot_PetitGap["C4_simu"] = C_4
# data_plot_PetitGap["Kurtosis_simu"] = Kurtosis
# data_plot_PetitGap["indice des \tau_1_2_3"] = np.array([Ntau1, Ntau2, Ntau3])
# data_plot_PetitGap["coef:A4,D4,C4"] = np.array([A4_theo_x, D4_long_theo, C4_long_theo])
# data_plot_PetitGap["Dpara_mean"] = mean_Dx
# data_plot_PetitGap["x_theo, PDF_theo_shortTime"] = dxx, PDF_theo_court
# data_plot_PetitGap["x, PDF1"] = np.array([dx_1, Mean1])
# data_plot_PetitGap["x, PDF2"] = np.array([dx_2, Mean2])
# data_plot_PetitGap["x, PDF3"] = np.array([dx_3, Mean3])

# from scipy.io import savemat
# savemat("DataFigureS3_PetitGap.mat", data_plot_PetitGap)
